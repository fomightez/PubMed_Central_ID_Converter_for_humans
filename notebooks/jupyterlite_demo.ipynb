# %% [markdown]
# ## Trying the PubMed Central ID Converter for humans in JupyterLite
#
# > "A simple library for using the PubMed Central ID Convert API for dealing biomedical and scientific literature in modern Python/Jupyter ecosystems."
#
# Here the demonstration of this package is done in JupyterLite.

# %% [markdown]
# ----------------
#
# # Use `pmc_id_converter` via Python
#
#
# Using the functionality of the `pmc_id_converter` via `import` is the easiest if you are using Python or a Python-based Jupyter kernel.
#
# I think this offers much more functionality than the command line if you are going to be using this with Python or Jupyter with a Python-based kernel. Therefor, as it has some more options and abilities than the command line, I'll try to provide examples illustrating many of the options.
#
# Since you may be using this where you'd like, and just using my repo a guiding 'how-to' example, I am going to include installing the script and associated dependencies from the basics. So first run the next cell to set up this environment with the needed dependencies. If you already have them where you are working, you'd skip this step.

# %%
# %pip install requests pandas

# %% [markdown]
# The main functionality of the script is in [the file `core.py` in the package repo](https://github.com/fomightez/PubMed_Central_ID_Converter_for_humans/blob/main/src/PMC_ID_Converter_for_humans/core.py), and so all we really need is to get that. Running the next cell will do that. We'll first set a Python string that is that address and then get that. We'll use `requests` since will need that for the script anyway.

# %%
url="https://raw.githubusercontent.com/fomightez/PubMed_Central_ID_Converter_for_humans/refs/heads/main/src/PMC_ID_Converter_for_humans/core.py"
import requests
def fetch_github_file_using_requests(the_url):
    """
    Take a url for a raw GitHub file and return the file content using GitHub's CORS-enabled REST API endpoint
    """
    response = requests.get(the_url)
    response.raise_for_status()  # Raise an exception for non-200 status codes
    return response.text
file_content_string = fetch_github_file_using_requests(url)
with open(url.rsplit("/", 1)[-1], 'w', encoding='utf-8') as output_file:
    output_file.write(file_content_string)

# %% [markdown]
# Let's verify that worked:

# %%
import os
os.listdir()
# Out:
# ['OLDjupyterlite_demo.ipynb',
#  'core.py',
#  'jupyterlite_demo.ipynb',
#  'pyodide',
#  'README.md',
#  'python.ipynb',
#  'data']

# %% [markdown]
# Let's first see what our current Python kernel sees as on the `Path` of our system:

# %%
import sys
sys.path
# Out:
# ['',
#  '/lib/python313.zip',
#  '/lib/python3.13',
#  '/lib/python3.13/lib-dynload',
#  '/lib/python3.13/site-packages',
#  '/drive']

# %% [markdown]
# Note, in your own case, if you know `core.py` is already included along that listing, then skip to trying `from core import PMC_id_convert` below. I am assuming you are using the offered JupyterLite session and working out how to adjust in that case. If you are working elsewhere, you may have to custmize this to set things up so that `from core import PMC_id_convert` works.
#
# LEt's see where we are on the present system with this next command to 'print working directory':

# %%
# %pwd
# Out:
# '/drive'

# %% [markdown]
# So we are in `/drive` and that is not on the list in the `Path` of our system lsited above by what `sys.path` shows, and so let's run the next cell to fix that:

# %%
import sys
sys.path.append('/drive')

# %% [markdown]
# And verify that was added:

# %%
import sys
sys.path
# Out:
# ['',
#  '/lib/python313.zip',
#  '/lib/python3.13',
#  '/lib/python3.13/lib-dynload',
#  '/lib/python3.13/site-packages',
#  '/drive']

# %% [markdown]
# If where you put `core.py` was already on the `Path` of your system, or you could move it to there. You wouldn't need the above step.

# %% [markdown]
# So now we should be ready to run `from core import PMC_id_convert` and have it work. However, I know from recent experience that just adding the path with `core` to the `Path` isn't enough for JupyterLite. We are going to invalidate the current cache and make sure we redo eveything and then import:

# %%
import importlib
importlib.invalidate_caches()
# %pip install requests pandas

# %%
# Now the main import we have been setting up to perform
from core import PMC_id_convert

# %% [markdown]
# Now we are fully set to use the functionality provided by the code, and **once you replace the text `<your_email_here>` in the first case with your email**, you  can run the following code block to demonstrate a way to use the script in JupyterLite:

# %%
PMC_id_convert('PMC3531190', email = '<YOUR_EMAIL_NEEDS_TO_BE_HERE>')
# Out:
# A dataframe of the data has been saved as a file in a manner where other software can access it (comma-separated form).
# RESULTING DATAFRAME is stored as ==> 'PMC_id_convert_output_df.csv'.
# A dataframe of the data has been saved as a file in a manner where other Python programs can access it (pickled form).
# RESULTING DATAFRAME is stored as ==> 'PMC_id_convert_output_df.pkl'.

# %% [markdown]
# In an ideal world, you'd now be ready to run the following code block to demonstrate many ways to use the script in JupyterLite. And some may work, but most likely will encounter one not working because of network issues and disrupt these all running. But you can at least examine the code and adapt to your needs:
# WAIT, just move to markdwon put output for each in turn below each!! Then say to use the proper demo to really run several.

# %%
# PMCID
PMC_id_convert('PMC3531190', email = '<YOUR_EMAIL_NEEDS_TO_BE_HERE>')

# Wait a bit before next request
import time
time.sleep(2)  # 2 second delay

# Multiple IDs
PMC_id_convert('PMC3531190, PMC3531191123, PMC3531191')

# Wait a bit before next request
time.sleep(2)  # 2 second delay

# PMID
PMC_id_convert('23193287')

# Wait a bit before next request
time.sleep(2)  # 2 second delay

# DOI
PMC_id_convert('10.1093/nar/gks1195')

# Wait a bit before next request
time.sleep(2)  # 2 second delay

# multiple DOIs
PMC_id_convert('10.1093/nar/gks1195,10.1007/s13205-018-1330-z')

# Wait a bit before next request
time.sleep(2)  # 2 second delay

# Output data as a dataframe with dataframe displayed as well (will render in nice style in Jupyter)
PMC_id_convert('PMC3531190,PMC3531191123,PMC3531191', return_df = True)

# Wait a bit before next request
time.sleep(2)  # 2 second delay


# Output data as a dataframe and force a string representation to display, even in Jupyter
print(PMC_id_convert('PMC3531190,PMC3531191123,PMC3531191', return_df = True))

# Wait a bit before next request
time.sleep(2)  # 2 second delay

# Output data as a dataframe with the file named with a custom prefix  
PMC_id_convert('PMC3531190,PMC3531191123,PMC3531191', output_prefix = 'custom_file_name_suffix')

# Wait a bit before next request
time.sleep(2)  # 2 second delay

# Python list as input
python_list_ids = ['PMC3531190','PMC3531191123','PMC3531191']
id_list_as_text = ','.join(python_list_ids)
PMC_id_convert(id_list_as_text, output_prefix = 'shows_can_use_list')

# Wait a bit before next request
time.sleep(2)  # 2 second delay

# Output data as list of dictionaries
list_of_result_dicts = PMC_id_convert('PMC3531190, PMC3531191', outform = 'dictionaries')

# Wait a bit before next request
time.sleep(2)  # 2 second delay

# Output data as a JSON text string
print(PMC_id_convert('PMC3531190, PMC3531191', outform = 'json'))


# Wait a bit before next request
time.sleep(2)  # 2 second delay

# Output data as a JSONL (JSON Lines) text string
print(PMC_id_convert('PMC3531190, PMC3531191', outform = 'jsonl'))

# Wait a bit before next request
time.sleep(2)  # 2 second delay

# Output data as JSON text & redirect that to a file when running in IPython/Jupyter
result = PMC_id_convert('PMC3531190, PMC3531191', outform = 'json')
# %store result >output.txt

# Wait a bit before next request
time.sleep(2)  # 2 second delay

# Output data as JSONL (JSON Lines) text  & redirect that to a file when running in IPython/Jupyter
result = PMC_id_convert('PMC3531190, PMC3531191', outform = 'jsonl')
# %store result >output.txt

# Wait a bit before next request
time.sleep(2)  # 2 second delay

# Output data as JSON text & redirect that to a file when running in standard Python
result = PMC_id_convert('PMC3531190, PMC3531191', outform='json')
with open('output.txt', 'w') as f:
    f.write(result)

# Wait a bit before next request
time.sleep(2)  # 2 second delay

# Output data as JSONL (JSON Lines) text  & redirect that to a file when running in standard Python
result = PMC_id_convert('PMC3531190, PMC3531191', outform='jsonl')
with open('output.txt', 'w') as f:
    f.write(result)
# Out:
# A dataframe of the data has been saved as a file in a manner where other software can access it (comma-separated form).
# RESULTING DATAFRAME is stored as ==> 'PMC_id_convert_output_df.csv'.
# A dataframe of the data has been saved as a file in a manner where other Python programs can access it (pickled form).
# RESULTING DATAFRAME is stored as ==> 'PMC_id_convert_output_df.pkl'.
# ---------------------------------------------------------------------------
# JsException                               Traceback (most recent call last)
# File /lib/python3.13/site-packages/urllib3/contrib/emscripten/fetch.py:529, in send_request(request)
#     527         js_xhr.setRequestHeader(name, value)
# --> 529 js_xhr.send(to_js(request.body))
#     531 headers = dict(Parser().parsestr(js_xhr.getAllResponseHeaders()))
#
# JsException: NetworkError: Failed to execute 'send' on 'XMLHttpRequest': Failed to load 'https://api.allorigins.win/raw?url=https%3A%2F%2Fpmc.ncbi.nlm.nih.gov%2Ftools%2Fidconv%2Fapi%2Fv1%2Farticles%2F%3Fids%3DPMC3531190%2C%20PMC3531191123%2C%20PMC3531191%26format%3Djson%26tool%3DPMC_ID_Converter_for_humans%26email%3Dthe_test%40example.com'.
#
# During handling of the above exception, another exception occurred:
#
# _RequestError                             Traceback (most recent call last)
# File /lib/python3.13/site-packages/urllib3/contrib/emscripten/connection.py:118, in EmscriptenHTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     117     if self._response is None:
# --> 118         self._response = send_request(request)
#     119 except _TimeoutError as e:
#
# File /lib/python3.13/site-packages/urllib3/contrib/emscripten/fetch.py:544, in send_request(request)
#     543 elif err.name == "NetworkError":
# --> 544     raise _RequestError(err.message, request=request)
#     545 else:
#     546     # general http error
#
# _RequestError: Failed to execute 'send' on 'XMLHttpRequest': Failed to load 'https://api.allorigins.win/raw?url=https%3A%2F%2Fpmc.ncbi.nlm.nih.gov%2Ftools%2Fidconv%2Fapi%2Fv1%2Farticles%2F%3Fids%3DPMC3531190%2C%20PMC3531191123%2C%20PMC3531191%26format%3Djson%26tool%3DPMC_ID_Converter_for_humans%26email%3Dthe_test%40example.com'.
#
# The above exception was the direct cause of the following exception:
#
# HTTPException                             Traceback (most recent call last)
# File /lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File /lib/python3.13/site-packages/urllib3/connectionpool.py:493, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     492 try:
# --> 493     conn.request(
#     494         method,
#     495         url,
#     496         body=body,
#     497         headers=headers,
#     498         chunked=chunked,
#     499         preload_content=preload_content,
#     500         decode_content=decode_content,
#     501         enforce_content_length=enforce_content_length,
#     502     )
#     504 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     505 # legitimately able to close the connection after sending a valid response.
#     506 # With this behaviour, the received response is still readable.
#
# File /lib/python3.13/site-packages/urllib3/contrib/emscripten/connection.py:122, in EmscriptenHTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     121 except _RequestError as e:
# --> 122     raise HTTPException(e.message) from e
#
# HTTPException: Failed to execute 'send' on 'XMLHttpRequest': Failed to load 'https://api.allorigins.win/raw?url=https%3A%2F%2Fpmc.ncbi.nlm.nih.gov%2Ftools%2Fidconv%2Fapi%2Fv1%2Farticles%2F%3Fids%3DPMC3531190%2C%20PMC3531191123%2C%20PMC3531191%26format%3Djson%26tool%3DPMC_ID_Converter_for_humans%26email%3Dthe_test%40example.com'.
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File /lib/python3.13/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File /lib/python3.13/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File /lib/python3.13/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File /lib/python3.13/site-packages/urllib3/util/util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File /lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File /lib/python3.13/site-packages/urllib3/connectionpool.py:493, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     492 try:
# --> 493     conn.request(
#     494         method,
#     495         url,
#     496         body=body,
#     497         headers=headers,
#     498         chunked=chunked,
#     499         preload_content=preload_content,
#     500         decode_content=decode_content,
#     501         enforce_content_length=enforce_content_length,
#     502     )
#     504 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     505 # legitimately able to close the connection after sending a valid response.
#     506 # With this behaviour, the received response is still readable.
#
# File /lib/python3.13/site-packages/urllib3/contrib/emscripten/connection.py:122, in EmscriptenHTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     121 except _RequestError as e:
# --> 122     raise HTTPException(e.message) from e
#
# ProtocolError: ('Connection aborted.', HTTPException("Failed to execute 'send' on 'XMLHttpRequest': Failed to load 'https://api.allorigins.win/raw?url=https%3A%2F%2Fpmc.ncbi.nlm.nih.gov%2Ftools%2Fidconv%2Fapi%2Fv1%2Farticles%2F%3Fids%3DPMC3531190%2C%20PMC3531191123%2C%20PMC3531191%26format%3Djson%26tool%3DPMC_ID_Converter_for_humans%26email%3Dthe_test%40example.com'."))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File /drive/core.py:313, in PMC_id_convert(ids, email, outform, return_df, output_prefix)
#     312 try:
# --> 313     res = requests.get(proxy_url)
#     314     res.raise_for_status()
#
# File /lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      63 r"""Sends a GET request.
#      64
#      65 :param url: URL for the new :class:`Request` object.
#    (...)     70 :rtype: requests.Response
#      71 """
# ---> 73 return request("get", url, params=params, **kwargs)
#
# File /lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File /lib/python3.13/site-packages/requests/adapters.py:682, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     681 except (ProtocolError, OSError) as err:
# --> 682     raise ConnectionError(err, request=request)
#     684 except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', HTTPException("Failed to execute 'send' on 'XMLHttpRequest': Failed to load 'https://api.allorigins.win/raw?url=https%3A%2F%2Fpmc.ncbi.nlm.nih.gov%2Ftools%2Fidconv%2Fapi%2Fv1%2Farticles%2F%3Fids%3DPMC3531190%2C%20PMC3531191123%2C%20PMC3531191%26format%3Djson%26tool%3DPMC_ID_Converter_for_humans%26email%3Dthe_test%40example.com'."))
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[31], line 5
#       2 PMC_id_convert('PMC3531190', email = 'the_test@example.com')
#       4 # Multiple IDs
# ----> 5 PMC_id_convert('PMC3531190, PMC3531191123, PMC3531191')
#       7 # PMID
#       8 PMC_id_convert('23193287')
#
# File /drive/core.py:316, in PMC_id_convert(ids, email, outform, return_df, output_prefix)
#     314     res.raise_for_status()
#     315 except requests.exceptions.RequestException as e:
# --> 316     raise Exception(
#     317         f"API request failed: {str(e)}\n"
#     318         f"This may be due to:\n"
#     319         f"  - Invalid email address: '{email}'\n"
#     320         f"  - Network connectivity issues\n"
#     321         f"  - NCBI API service problems\n"
#     322         f"Please verify your email is valid and try again.\n"
#     323     )
#     325 # Check if we got HTML (error) instead of expected format
#     326 if res.text.strip().startswith('<'):
#
# Exception: API request failed: ('Connection aborted.', HTTPException("Failed to execute 'send' on 'XMLHttpRequest': Failed to load 'https://api.allorigins.win/raw?url=https%3A%2F%2Fpmc.ncbi.nlm.nih.gov%2Ftools%2Fidconv%2Fapi%2Fv1%2Farticles%2F%3Fids%3DPMC3531190%2C%20PMC3531191123%2C%20PMC3531191%26format%3Djson%26tool%3DPMC_ID_Converter_for_humans%26email%3Dthe_test%40example.com'."))
# This may be due to:
#   - Invalid email address: 'the_test@example.com'
#   - Network connectivity issues
#   - NCBI API service problems
# Please verify your email is valid and try again.

# %% [markdown]
# The delays add there are to not slam the proxy I found is needed for JupyterLite. It is a possible drawback that would suggests for certain uses, a typical Python kernel not running with WASM may be a better choice for some uses.

# %% [markdown]
# Huh. Now the proxy isn't working conssitently!??! Maybe set it to not tax it so much with that whole block. Like put each one in a different cell? (for now, I tried adding a delay.
# Pandas works, right?

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('PMC_id_convert_output_df.csv')
df
# Out:
#                    doi       pmcid      pmid requested-id
# 0  10.1093/nar/gks1195  PMC3531190  23193287   PMC3531190

# %% [markdown]
# --------
#
# # Use via a Command Line-like interface  WAIT MOVE THIS UNTIL SECOND, SINCE ODD!! And other way more like `import` with ipyKERNEL !!!!
#
# NOTE:
# JupyterLite doesn't have a bash command shell, so we are going to use Jupyter/IPython `%run` magic to use it similarly where we can provide the ids to act on in the command.
#
# To do this so it easy to follow, we are going to place the main script alongside this notebook.

# %%
# %pwd
# Out:
# '/drive'

# %%
#copy the main script to where this notebook is
import os
os.getcwd()
# Out:
# '/drive/PubMed_Central_ID_Converter_for_humans/notebooks'

# %%
import os
os.listdir()
# Out:
# ['jupyterlite_demo.ipynb']

# %%
from pathlib import Path
# Move to a different directory
Path("/drive/PubMed_Central_ID_Converter_for_humans/src/PMC_ID_Converter_for_humans/core.py").rename("/drive/PubMed_Central_ID_Converter_for_humans/notebooks/core.py")
# Out:
# PosixPath('/drive/PubMed_Central_ID_Converter_for_humans/notebooks/core.py')

# %%
import os
os.listdir()
# Out:
# ['core.py', 'jupyterlite_demo.ipynb']

# %% [markdown]
# Now to try to run the core script:

# %%
# %run core_test.py PMC3531190 --email <your_mail_here>

# %% [markdown]
# --------
#
# ## Advanced Python Use
#
# Pandas is common to use when doing data science in Python and it offers easier handling of large collections of data.
# In this section I provide examples integrating use of `????????????` and Pandas.
#
# For making a dataframe of the results in memore from examples like `PMC_id_convert_output_df.csv`.....

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('PMC_id_convert_output_df.csv')
df
# Out:
#                    doi       pmcid      pmid requested-id
# 0  10.1093/nar/gks1195  PMC3531190  23193287   PMC3531190

# %% [markdown]
# ------
#
# Enjoy!
